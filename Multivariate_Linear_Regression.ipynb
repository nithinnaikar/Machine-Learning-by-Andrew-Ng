# %%
# Importing necessary libraries
import numpy
import sklearn
import matplotlib

# %%
# Initializing the dataset
dataset = numpy.loadtxt(fname = "/content/ex1data2.txt", delimiter = ",")
print("Dataset:\n\n{}\n\nShape:{}".format(dataset, dataset.shape))
# Out:
# Dataset:
#
# [[2.10400e+03 3.00000e+00 3.99900e+05]
#  [1.60000e+03 3.00000e+00 3.29900e+05]
#  [2.40000e+03 3.00000e+00 3.69000e+05]
#  [1.41600e+03 2.00000e+00 2.32000e+05]
#  [3.00000e+03 4.00000e+00 5.39900e+05]
#  [1.98500e+03 4.00000e+00 2.99900e+05]
#  [1.53400e+03 3.00000e+00 3.14900e+05]
#  [1.42700e+03 3.00000e+00 1.98999e+05]
#  [1.38000e+03 3.00000e+00 2.12000e+05]
#  [1.49400e+03 3.00000e+00 2.42500e+05]
#  [1.94000e+03 4.00000e+00 2.39999e+05]
#  [2.00000e+03 3.00000e+00 3.47000e+05]
#  [1.89000e+03 3.00000e+00 3.29999e+05]
#  [4.47800e+03 5.00000e+00 6.99900e+05]
#  [1.26800e+03 3.00000e+00 2.59900e+05]
#  [2.30000e+03 4.00000e+00 4.49900e+05]
#  [1.32000e+03 2.00000e+00 2.99900e+05]
#  [1.23600e+03 3.00000e+00 1.99900e+05]
#  [2.60900e+03 4.00000e+00 4.99998e+05]
#  [3.03100e+03 4.00000e+00 5.99000e+05]
#  [1.76700e+03 3.00000e+00 2.52900e+05]
#  [1.88800e+03 2.00000e+00 2.55000e+05]
#  [1.60400e+03 3.00000e+00 2.42900e+05]
#  [1.96200e+03 4.00000e+00 2.59900e+05]
#  [3.89000e+03 3.00000e+00 5.73900e+05]
#  [1.10000e+03 3.00000e+00 2.49900e+05]
#  [1.45800e+03 3.00000e+00 4.64500e+05]
#  [2.52600e+03 3.00000e+00 4.69000e+05]
#  [2.20000e+03 3.00000e+00 4.75000e+05]
#  [2.63700e+03 3.00000e+00 2.99900e+05]
#  [1.83900e+03 2.00000e+00 3.49900e+05]
#  [1.00000e+03 1.00000e+00 1.69900e+05]
#  [2.04000e+03 4.00000e+00 3.14900e+05]
#  [3.13700e+03 3.00000e+00 5.79900e+05]
#  [1.81100e+03 4.00000e+00 2.85900e+05]
#  [1.43700e+03 3.00000e+00 2.49900e+05]
#  [1.23900e+03 3.00000e+00 2.29900e+05]
#  [2.13200e+03 4.00000e+00 3.45000e+05]
#  [4.21500e+03 4.00000e+00 5.49000e+05]
#  [2.16200e+03 4.00000e+00 2.87000e+05]
#  [1.66400e+03 2.00000e+00 3.68500e+05]
#  [2.23800e+03 3.00000e+00 3.29900e+05]
#  [2.56700e+03 4.00000e+00 3.14000e+05]
#  [1.20000e+03 3.00000e+00 2.99000e+05]
#  [8.52000e+02 2.00000e+00 1.79900e+05]
#  [1.85200e+03 4.00000e+00 2.99900e+05]
#  [1.20300e+03 3.00000e+00 2.39500e+05]]
#
# Shape:(47, 3)

# %%
# Dividing and reshaping the dataset into training and testing segments
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(dataset[:, :2],
                                                                            dataset[:, 2],
                                                                            test_size = 0.1)

# %%
# Visualizing the 42x2 input feaure matrix 
print("X_train:\n\n{}\n\nShape:{}".format(X_train, X_train.shape))
# Out:
# X_train:
#
# [[1.767e+03 3.000e+00]
#  [1.458e+03 3.000e+00]
#  [1.380e+03 3.000e+00]
#  [1.200e+03 3.000e+00]
#  [1.236e+03 3.000e+00]
#  [2.609e+03 4.000e+00]
#  [2.400e+03 3.000e+00]
#  [2.200e+03 3.000e+00]
#  [2.526e+03 3.000e+00]
#  [3.137e+03 3.000e+00]
#  [1.416e+03 2.000e+00]
#  [1.268e+03 3.000e+00]
#  [1.600e+03 3.000e+00]
#  [2.162e+03 4.000e+00]
#  [1.888e+03 2.000e+00]
#  [1.811e+03 4.000e+00]
#  [2.238e+03 3.000e+00]
#  [2.132e+03 4.000e+00]
#  [1.203e+03 3.000e+00]
#  [1.985e+03 4.000e+00]
#  [1.664e+03 2.000e+00]
#  [2.567e+03 4.000e+00]
#  [1.494e+03 3.000e+00]
#  [1.320e+03 2.000e+00]
#  [1.239e+03 3.000e+00]
#  [2.000e+03 3.000e+00]
#  [1.100e+03 3.000e+00]
#  [1.852e+03 4.000e+00]
#  [4.478e+03 5.000e+00]
#  [1.437e+03 3.000e+00]
#  [8.520e+02 2.000e+00]
#  [3.031e+03 4.000e+00]
#  [1.534e+03 3.000e+00]
#  [1.000e+03 1.000e+00]
#  [3.000e+03 4.000e+00]
#  [1.962e+03 4.000e+00]
#  [1.890e+03 3.000e+00]
#  [3.890e+03 3.000e+00]
#  [1.427e+03 3.000e+00]
#  [2.637e+03 3.000e+00]
#  [1.839e+03 2.000e+00]
#  [4.215e+03 4.000e+00]]
#
# Shape:(42, 2)

# %%
# Visualizing the 42x1 output target vector
print("y_train:\n\n{}\n\nShape:{}".format(y_train, y_train.shape))
# Out:
# y_train:
#
# [252900. 464500. 212000. 299000. 199900. 499998. 369000. 475000. 469000.
#  579900. 232000. 259900. 329900. 287000. 255000. 285900. 329900. 345000.
#  239500. 299900. 368500. 314000. 242500. 299900. 229900. 347000. 249900.
#  299900. 699900. 249900. 179900. 599000. 314900. 169900. 539900. 259900.
#  329999. 573900. 198999. 299900. 349900. 549000.]
#
# Shape:(42,)

# %%
# Visualizing the training data
figure = matplotlib.pyplot.figure()
graph = figure.add_subplot(projection = "3d")
graph.scatter3D(xs = X_train[:, 0], ys = X_train[:, 1], zs = y_train)
graph.set_xlabel("House Size")
graph.set_ylabel("Number of Bedrooms")
graph.set_zlabel("Price")
# Out:
# Text(0.5, 0, 'Price')

# %%
# Initializing the model
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept = True)

# %%
# Optimizing the model
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.intercept_
# Out:
# 86800.76308806587

# %%
# Visualizing the optimized model
figure = matplotlib.pyplot.figure()
graph = figure.add_subplot(projection = "3d")
graph.scatter3D(xs = X_train[:, 0], ys = X_train[:, 1], zs = y_train)
xs = numpy.linspace(1000, 4500)
ys = numpy.linspace(1.0, 5.0)
zs = model.coef_[0] * xs + model.coef_[1] * ys + model.intercept_
graph.plot3D(xs, ys, zs)
graph.set_xlabel("House Size")
graph.set_ylabel("Number of Bedrooms")
graph.set_zlabel("Price")
# Out:
# Text(0.5, 0, 'Price')
